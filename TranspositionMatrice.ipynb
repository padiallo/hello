# %% [markdown]
# <a href="https://colab.research.google.com/github/padiallo/hello/blob/main/TranspositionMatrice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

Mat = np.random.randn(2,8)
MatT = Mat.T
#MatT = np.transpose(Mat)

fig,ax=plt.subplots(1,2)

ax[0].imshow(Mat)
ax[0].set_title("Mat")
ax[0].set_xticks([]) #Enleve les libellés des points de l'axe des x

ax[1].imshow(MatT)
ax[1].set_title("Mat$^T$")
ax[1].set_xticks([]) #Enleve les libellés des points de l'axe des x

#for i in ax:
#  i.set_xticks([])
#  i.set_yticks([])
#Ce code remplace plusieurs lignes de code
plt.show()
